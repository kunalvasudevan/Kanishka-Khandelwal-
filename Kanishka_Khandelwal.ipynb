# %% [markdown]
# <a href="https://colab.research.google.com/github/kunalvasudevan/Kanishka-Khandelwal-/blob/master/Kanishka_Khandelwal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Header file**

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Uploading the Excel sheet**

# %%
Dataset = pd.read_excel('college names.xlsx')

# %% [markdown]
# # **Showing top 5 rows**

# %%
Dataset.head()
# Out:
#    Sno  ...     GOPENH
# 0    1  ...  73.196556
# 1    2  ...  55.655294
# 2    3  ...  88.110774
# 3    4  ...  50.407364
# 4    5  ...        NaN
#
# [5 rows x 4 columns]

# %% [markdown]
# # **Showing bottom 5 rows**

# %%
Dataset.tail()
# Out:
#      Sno                      Home College  ...     GOPENH  jee_PassStatus
# 100  100  Savitribai Phule Pune University  ...  62.303108            Fail
# 101  101  Savitribai Phule Pune University  ...        NaN            Pass
# 102  102  Savitribai Phule Pune University  ...        NaN            Pass
# 103  103  Savitribai Phule Pune University  ...  69.112056            Fail
# 104  104  Savitribai Phule Pune University  ...   6.232121            Fail
#
# [5 rows x 5 columns]

# %% [markdown]
# # **Getting the information**

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sno           105 non-null    int64
#  1   Home College  105 non-null    object
#  2   College       105 non-null    object
#  3   GOPENH        75 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.4+ KB

# %%
Dataset.describe().T
# Out:
#         count       mean        std  ...        50%        75%         max
# Sno     105.0  52.428571  30.029747  ...  52.000000  78.000000  104.000000
# GOPENH   75.0  39.328182  32.429672  ...  31.405749  71.455031   99.372479
#
# [2 rows x 8 columns]

# %% [markdown]
# # **Checking for the null value**

# %%
Dataset.isna().apply(pd.value_counts)
# Out:
#          Sno  Home College  College   GOPENH
# False  105.0         105.0     105.0      75
# True     NaN           NaN       NaN      30

# %%
Dataset.isnull().sum()
# Out:
# Sno              0
# Home College     0
# College          0
# GOPENH          30
# dtype: int64

# %% [markdown]
# # **Checking if any cutoff is zero or not**

# %%
any(Dataset['GOPENH'] == 0)
# Out:
# False

# %%
(Dataset.Sno > 0).value_counts()
# Out:
# True    105
# Name: Sno, dtype: int64

# %%
(Dataset.Sno > 0).sum()
# Out:
# 105

# %%
(Dataset.GOPENH> 0).value_counts()
# Out:
# True     75
# False    30
# Name: GOPENH, dtype: int64

# %%
(Dataset.GOPENH> 90).sum()
# Out:
# 5

# %%
(Dataset.GOPENH>90).value_counts().to_frame()
# Out:
#        GOPENH
# False     100
# True        5

# %% [markdown]
# # **Highest cutoff**

# %%
print("Maximum cutoff of the college in Savitribai Phule Pune University:", max(Dataset.GOPENH))
# Out:
# Maximum cutoff of the college in Savitribai Phule Pune University: 99.3724789

# %%
print("Minimum cutoff of the college in Savitribai Phule Pune University :", min(Dataset.GOPENH))
# Out:
# Minimum cutoff of the college in Savitribai Phule Pune University : 0.2770073

# %%
print(Dataset.GOPENH)
# Out:
# 0      73.196556
# 1      55.655294
# 2      88.110774
# 3      50.407364
# 4            NaN
#          ...
# 100    62.303108
# 101          NaN
# 102          NaN
# 103    69.112056
# 104     6.232121
# Name: GOPENH, Length: 105, dtype: float64

# %%
sns.distplot(Dataset['GOPENH'])

# %%
Dataset['cutoff_PassStatus'] = np.where(Dataset['GOPENH']<90, 'Fail', 'Pass')

# %%
Dataset['cutoff_PassStatus'].value_counts()
# Out:
# Fail    70
# Pass    35
# Name: cutoff_PassStatus, dtype: int64

# %%
n = Dataset.GOPENH>90
for i in n:
  {
  print('College = ',Dataset.GOPENH)   
  }
# Out:
# College =  0      73.196556
# 1      55.655294
# 2      88.110774
# 3      50.407364
# 4            NaN
#          ...
# 100    62.303108
# 101          NaN
# 102          NaN
# 103    69.112056
# 104     6.232121
# Name: GOPENH, Length: 105, dtype: float64
# College =  0      73.196556
# 1      55.655294
# 2      88.110774
# 3      50.407364
# 4            NaN
#          ...
# 100    62.303108
# 101          NaN
# 102          NaN
# 103    69.112056
# 104     6.232121
# Name: GOPENH, Length: 105, dtype: float64
# College =  0      73.196556
# 1      55.655294
# 2      88.110774
# 3      50.407364
# 4            NaN
#          ...
# 100    62.303108
# 101          NaN
# 102          NaN
# 103    69.112056
# 104     6.232121
# Name: GOPENH, Length: 105, dtype: float64
# College =  0      73.196556
# 1      55.655294
# 2      88.110774
# 3      50.407364
# 4            NaN
#          ...
# 100    62.303108
# 101          NaN
# 102          NaN
# 103    69.112056
# 104     6.232121
# ...
